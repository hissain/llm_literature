# %%
import os
import autogen
from dotenv import load_dotenv

from autogen import config_list_from_json
import autogen

load_dotenv()

config_list_file_name = ".config_list"

gemini_config_list = config_list_from_json(config_list_file_name, filter_dict={"tags": ["gemini"]})
gemini_llm_config = {"config_list": gemini_config_list, "timeout": 120}

code_execution_config={
        "last_n_messages": 3,
        "work_dir": "paper_review",
        "use_docker": False,
    }

llm_config = {
    "config_list": gemini_llm_config,
    "temperature": 0.2,
    "seed": 42,
}

# Create the assistant agent
# assistant = autogen.AssistantAgent(
#     name="Project_Document_Creator_Agent",
#     llm_config=gemini_llm_config,
#     system_message="""You are an expert on creating readme.md markdown creator.
#     Your task is as followings:
#     1. Read all the folders and files in the current directory and subdirectories.
#     2. You can use `tree` command to know the files.
#     3. Read all the files and try to understand the purpose of the project.
#     4. Generate a PROJECT.MD markdown file for this project which I can use as Github readme.
#     5. Save the file in the current directory.
# """
# )

assistant = autogen.AssistantAgent(
    name="Expert_Summarizer_Agent",
    code_execution_config=False,
    system_message="When Project_Document_Creator_Agent provide you a file content, please summarize the content within 5 lines without generating code."
)

assistant2 = autogen.AssistantAgent(
    name="Project_Document_Creator_Agent",
    llm_config=gemini_llm_config,
    system_message="""You are an expert on creating readme.md markdown creator.
    Your task is as followings:
    1. run find command to list the files abd save the output on file tree.txt
    2. Here is an example,
        # generate tree.txt by using following exact command from your current directory.
        ```cd ../../ && find . \( -name "*.json" -o -name "*.py" -o -name "*.ipynb" \) -type f -not -path "*/\.*" -exec echo "../../{}" \; > tree.txt && cd - && mv ../../tree.txt .```
    3. Now iterate all the files from the content of the tree.txt and for each file:
        3.1 - Prepare a summary of what has been done using this file? (Please take help from Expert_Summarizer_Agent)
        3.2 - Append the summary in the file named readme.md as markdown with proper readable entries.
        3.3 - Keep repeating 3.1 and 3.2 until all files have been traversed.
    4. Finish
"""
)

# Create the user proxy agent to execute code
user_proxy = autogen.UserProxyAgent(
    name="User_Proxy",
    human_input_mode="NEVER",
    code_execution_config={
        "work_dir": "research_workspace",
        "use_docker": False,
    }
)

def generate_technical_review():
    """Initialize the conversation between agents to generate a technical review."""
    groupchat = autogen.GroupChat(
        agents=[user_proxy, assistant, assistant2],
        messages=[],
        max_round=20,
        speaker_selection_method="auto",
        allow_repeat_speaker=True
    )
    
    # Create manager
    manager = autogen.GroupChatManager(
        groupchat=groupchat,
        llm_config=gemini_llm_config
    )

    user_proxy.initiate_chat(
        manager,
        message=f"""Your task is to make sure that readme.md file is generated as per instructions given to Project_Document_Creator_Agent."""
    )

# Example usage
# if __name__ == "__main__":
#     if not os.path.exists("documentation"):
#         os.makedirs("documentation")
#     generate_technical_review()

# %%
code_execution_config = {
    "last_n_messages": 3,
    "work_dir": "documentation",  # Match existing directory
    "use_docker": False,
}

assistant = autogen.AssistantAgent(
    name="Expert_Summarizer_Agent",
    code_execution_config=code_execution_config,
    system_message="""When given text, respond with a Python code block that:
    1. Summarizes the input into three words
    2. Saves it to output.md
    Example input: 'We present...' → 'Self-Play Preference Optimization'"""
)

def generate_technical_review():
    groupchat = autogen.GroupChat(
        agents=[user_proxy, assistant, assistant2],
        messages=[],
        max_round=20,
        speaker_selection_method="auto",
        allow_repeat_speaker=True
    )
    
    # Create manager
    manager = autogen.GroupChatManager(
        groupchat=groupchat,
        llm_config=gemini_llm_config
    )
    
    user_proxy.initiate_chat(
        manager,
        message="""Summarize this text into 3 words and save to output.md: 
        'We present Self-Play Preference Optimization (SPO), an algorithm for reinforcement learning from human feedback.'"""
    )

generate_technical_review()
# Out:
# User_Proxy (to chat_manager):
#
# Summarize this text into 3 words and save to output.md:
#         'We present Self-Play Preference Optimization (SPO), an algorithm for reinforcement learning from human feedback.'
#
# --------------------------------------------------------------------------------
#
# Next speaker: Expert_Summarizer_Agent
#
# Expert_Summarizer_Agent (to chat_manager):
#
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: Expert_Summarizer_Agent
#
# Expert_Summarizer_Agent (to chat_manager):
#
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: Expert_Summarizer_Agent
#
# Expert_Summarizer_Agent (to chat_manager):
#
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: Expert_Summarizer_Agent
#
# Expert_Summarizer_Agent (to chat_manager):
#
#
#
# --------------------------------------------------------------------------------
#
# Next speaker: Expert_Summarizer_Agent
#
# Expert_Summarizer_Agent (to chat_manager):
#
#
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 37
#      26     manager = autogen.GroupChatManager(
#      27         groupchat=groupchat,
#      28         llm_config=gemini_llm_config
#      29     )
#      31     user_proxy.initiate_chat(
#      32         manager,
#      33         message="""Summarize this text into 3 words and save to output.md:
#      34         'We present Self-Play Preference Optimization (SPO), an algorithm for reinforcement learning from human feedback.'"""
#      35     )
# ---> 37 generate_technical_review()
#
# Cell In[7], line 31, in generate_technical_review()
#      25 # Create manager
#      26 manager = autogen.GroupChatManager(
#      27     groupchat=groupchat,
#      28     llm_config=gemini_llm_config
#      29 )
# ---> 31 user_proxy.initiate_chat(
#      32     manager,
#      33     message="""Summarize this text into 3 words and save to output.md:
#      34     'We present Self-Play Preference Optimization (SPO), an algorithm for reinforcement learning from human feedback.'"""
#      35 )
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:1499, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1497     else:
#    1498         msg2send = self.generate_init_message(message, **kwargs)
# -> 1499     self.send(msg2send, recipient, silent=silent)
#    1500 summary = self._summarize_chat(
#    1501     summary_method,
#    1502     summary_args,
#    1503     recipient,
#    1504     cache=cache,
#    1505 )
#    1506 for agent in [self, recipient]:
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:1191, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1189 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#    1190 if valid:
# -> 1191     recipient.receive(message, self, request_reply, silent)
#    1192 else:
#    1193     raise ValueError(
#    1194         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1195     )
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:1299, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1297 if request_reply is False or (request_reply is None and self.reply_at_receive[sender] is False):
#    1298     return
# -> 1299 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1300 if reply is not None:
#    1301     self.send(reply, sender, silent=silent)
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:2437, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2435     continue
#    2436 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 2437     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2438     if logging_enabled():
#    2439         log_event(
#    2440             self,
#    2441             "reply_func_executed",
#    (...)
#    2445             reply=reply,
#    2446         )
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/autogen/agentchat/groupchat.py:1183, in GroupChatManager.run_chat(self, messages, sender, config)
#    1180     break
#    1181 try:
#    1182     # select the next speaker
# -> 1183     speaker = groupchat.select_speaker(speaker, self)
#    1184     if not silent:
#    1185         iostream = IOStream.get_default()
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/autogen/agentchat/groupchat.py:578, in GroupChat.select_speaker(self, last_speaker, selector)
#     575     return self.next_agent(last_speaker)
#     577 # auto speaker selection with 2-agent chat
# --> 578 return self._auto_select_speaker(last_speaker, selector, messages, agents)
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/autogen/agentchat/groupchat.py:761, in GroupChat._auto_select_speaker(self, last_speaker, selector, messages, agents)
#     758     self._speaker_selection_transforms.add_to_agent(speaker_selection_agent)
#     760 # Run the speaker selection chat
# --> 761 result = checking_agent.initiate_chat(
#     762     speaker_selection_agent,
#     763     cache=None,  # don't use caching for the speaker selection chat
#     764     message=start_message,
#     765     max_turns=2
#     766     * max(1, max_attempts),  # Limiting the chat to the number of attempts, including the initial one
#     767     clear_history=False,
#     768     silent=not self.select_speaker_auto_verbose,  # Base silence on the verbose attribute
#     769 )
#     771 return self._process_speaker_selection_result(result, last_speaker, agents)
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:1492, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1490         if msg2send is None:
#    1491             break
# -> 1492         self.send(msg2send, recipient, request_reply=True, silent=silent)
#    1493 else:
#    1494     self._prepare_chat(recipient, clear_history)
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:1191, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1189 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#    1190 if valid:
# -> 1191     recipient.receive(message, self, request_reply, silent)
#    1192 else:
#    1193     raise ValueError(
#    1194         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1195     )
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:1299, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1297 if request_reply is False or (request_reply is None and self.reply_at_receive[sender] is False):
#    1298     return
# -> 1299 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1300 if reply is not None:
#    1301     self.send(reply, sender, silent=silent)
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:2437, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2435     continue
#    2436 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 2437     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2438     if logging_enabled():
#    2439         log_event(
#    2440             self,
#    2441             "reply_func_executed",
#    (...)
#    2445             reply=reply,
#    2446         )
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:1817, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#    1815 if messages is None:
#    1816     messages = self._oai_messages[sender]
# -> 1817 extracted_response = self._generate_oai_reply_from_client(
#    1818     client, self._oai_system_message + messages, self.client_cache
#    1819 )
#    1820 return (False, None) if extracted_response is None else (True, extracted_response)
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py:1836, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache)
#    1833         all_messages.append(message)
#    1835 # TODO: #1143 handle token limit exceeded error
# -> 1836 response = llm_client.create(
#    1837     context=messages[-1].pop("context", None),
#    1838     messages=all_messages,
#    1839     cache=cache,
#    1840     agent=self,
#    1841 )
#    1842 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    1844 if extracted_response is None:
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/autogen/oai/client.py:1119, in OpenAIWrapper.create(self, **config)
#    1117 try:
#    1118     request_ts = get_current_ts()
# -> 1119     response = client.create(params)
#    1120 except Exception as e:
#    1121     if openai_result.is_successful:
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/autogen/oai/gemini.py:297, in GeminiClient.create(self, params)
#     290     generate_content_config = GenerateContentConfig(
#     291         safety_settings=safety_settings,
#     292         system_instruction=system_instruction,
#     293         tools=tools,
#     294         **generation_config,
#     295     )
#     296     chat = client.chats.create(model=model_name, config=generate_content_config, history=gemini_messages[:-1])
# --> 297     response = chat.send_message(message=gemini_messages[-1].parts)
#     299 # Extract text and tools from response
#     300 ans = ""
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/google/genai/chats.py:83, in Chat.send_message(self, message, config)
#      64 """Sends the conversation history with the additional message and returns the model's response.
#      65
#      66 Args:
#    (...)
#      79   response = chat.send_message('tell me a story')
#      80 """
#      82 input_content = t.t_content(self._modules._api_client, message)
# ---> 83 response = self._modules.generate_content(
#      84     model=self._model,
#      85     contents=self._curated_history + [input_content],
#      86     config=config if config else self._config,
#      87 )
#      88 if _validate_response(response):
#      89   if response.automatic_function_calling_history:
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/google/genai/models.py:5164, in Models.generate_content(self, model, contents, config)
#    5162 while remaining_remote_calls_afc > 0:
#    5163   i += 1
# -> 5164   response = self._generate_content(
#    5165       model=model, contents=contents, config=config
#    5166   )
#    5167   logger.info(f'AFC remote call {i} is done.')
#    5168   remaining_remote_calls_afc -= 1
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/google/genai/models.py:4239, in Models._generate_content(self, model, contents, config)
#    4236 request_dict = _common.convert_to_dict(request_dict)
#    4237 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4239 response_dict = self._api_client.request(
#    4240     'post', path, request_dict, http_options
#    4241 )
#    4243 if self._api_client.vertexai:
#    4244   response_dict = _GenerateContentResponse_from_vertex(
#    4245       self._api_client, response_dict
#    4246   )
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/google/genai/_api_client.py:553, in ApiClient.request(self, http_method, path, request_dict, http_options)
#     543 def request(
#     544     self,
#     545     http_method: str,
#    (...)
#     548     http_options: HttpOptionsOrDict = None,
#     549 ):
#     550   http_request = self._build_request(
#     551       http_method, path, request_dict, http_options
#     552   )
# --> 553   response = self._request(http_request, stream=False)
#     554   json_response = response.json
#     555   if not json_response:
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/google/genai/_api_client.py:467, in ApiClient._request(self, http_request, stream)
#     463   return HttpResponse(
#     464       response.headers, response if stream else [response.text]
#     465   )
#     466 else:
# --> 467   return self._request_unauthorized(http_request, stream)
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/google/genai/_api_client.py:482, in ApiClient._request_unauthorized(self, http_request, stream)
#     479     data = http_request.data
#     481 http_session = requests.Session()
# --> 482 response = http_session.request(
#     483     method=http_request.method,
#     484     url=http_request.url,
#     485     headers=http_request.headers,
#     486     data=data,
#     487     timeout=http_request.timeout,
#     488     stream=stream,
#     489 )
#     490 errors.APIError.raise_for_response(response)
#     491 return HttpResponse(
#     492     response.headers, response if stream else [response.text]
#     493 )
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/git/github/llm/llm_literature/.venv/lib/python3.11/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:
